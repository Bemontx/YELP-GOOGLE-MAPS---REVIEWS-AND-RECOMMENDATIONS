# %%
import pandas as pd

# %%
df = pd.read_parquet('./google_busisness.parquet')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7778 entries, 0 to 7777
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gmap_id         7778 non-null   object
#  1   name            7778 non-null   object
#  2   address         7778 non-null   object
#  3   state           7778 non-null   object
#  4   latitude        7778 non-null   float64
#  5   longitude       7778 non-null   float64
#  6   num_of_reviews  7778 non-null   int64
#  7   avg_rating      7778 non-null   float64
#  8   description     3445 non-null   object
#  9   category        7778 non-null   object
#  10  attributes      7778 non-null   object
#  11  calendar        6920 non-null   object
#  12  url             7778 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 790.1+ KB

# %%
df.to_parquet('google_busisness.parquet',index=False)

# %%
df.sample(10)
# Out:
#                                     gmap_id  \
# 6920  0x89c2584d918a25c5:0xbe1efdada753f964
# 7454  0x8640e6962b3d81f3:0xa0ab982d19900d15
# 7219  0x89c2f61b59f274f9:0xf99241792207ca0d
# 365   0x89c25977c7908ce7:0x85ebd9536ad49e3f
# 6477  0x80c2d089cd9297e3:0x7a360ee4627ec865
# 1531  0x89c259ea04c3897d:0x2a37840b2092531d
# 5122  0x8824c1789a0bf505:0xde1d11468e9b5e1c
# 6526  0x89c2596d5783c191:0xaa7dd02ec324640e
# 3946  0x89c25a3d36eee6db:0xdd3c7a6928624094
# 4245  0x89b763934be07381:0xf8d6b18bdcced918
#
#                                    name  \
# 6920        Happy Family Restaurant 新上海
# 7454                    Texas de Brazil
# 7219  Madison African Caribbean Cuisine
# 365                              Karahi
# 6477                              Focus
# 1531                        Mother Duck
# 5122         New York Burgers and Grill
# 6526                            Paisley
# 3946                         McDonald's
# 4245                     Domino's Pizza
#
# ...
